# %%
import requests
import json
resultsList=[]
resultList=requests.get("https://api.nytimes.com/svc/books/v3/lists/names.json?api-key=8f9f412055a44f1abb9b050ccab4fa3f").json()
dir='E:/Python-Data-Anaysis-Github/kuzhandaivel_NirmalAnand_Spring2017/midterm/data/question2'
articleDirectory=dir+'/'+'Article'

#Create the Directory Structure

if not os.path.exists(articleDirectory):
    os.makedirs(articleDirectory)
for listName in resultList['results']:
    bookList=[]
    bookList=requests.get("https://api.nytimes.com/svc/books/v3/lists.json?list="+listName['list_name']+"&api-key=8f9f412055a44f1abb9b050ccab4fa3f").json()
    with open(resultsDir+'\\'+listName['list_name_encoded']+'.json', 'w') as outfile:
        json.dump(bookList['results'], outfile)

# %%
import requests
import os
import json
booksList=[]
bookList=requests.get("https://api.nytimes.com/svc/books/v3/lists.json?list=Combined Print and E-Book Nonfiction&api-key=8f9f412055a44f1abb9b050ccab4fa3f").json()
resultsDir='Sample'
os.makedirs(resultsDir)
with open(resultsDir+'\\'+'sample.json', 'w') as outfile:
    json.dump(bookList['results'], outfile)
    print("Json dumped in folder")
# Out:
# Json dumped in folder

# %%
# Analysis to show how many books fall under each Category

import json
import glob
dataHash={}
for name in glob.iglob('E:/DataAnalysis4Python_Spring17/bookList/*.*'):
    with open(name,'r') as out:
        data=json.load(out)
        dataHash[data[1]['list_name']]=len(data)
print(dataHash)
# Out:
# {'Humor': 10, 'Trade Fiction Paperback': 10, 'E-Book Nonfiction': 15, 'Culture': 10, 'Hardcover Nonfiction': 15, 'Young Adult': 15, 'Family': 10, 'Series Books': 10, 'Chapter Books': 10, 'Childrens Middle Grade Paperback': 10, 'Games and Activities': 10, 'Expeditions Disasters and Adventures': 10, 'Business Books': 10, 'Combined Print Fiction': 20, 'Crime and Punishment': 10, 'Espionage': 10, 'Food and Fitness': 10, 'Picture Books': 10, 'Manga': 10, 'Animals': 10, 'Young Adult E-Book': 5, 'Combined Print and E-Book Fiction': 15, 'Childrens Middle Grade Hardcover': 10, 'Paperback Advice': 15, 'Paperback Graphic Books': 10, 'Combined Print Nonfiction': 20, 'Childrens Middle Grade E-Book': 5, 'Fashion Manners and Customs': 10, 'Young Adult Paperback': 10, 'Health': 10, 'Hardcover Graphic Books': 10, 'Young Adult Hardcover': 10, 'Mass Market Paperback': 15, 'Hardcover Political Books': 10, 'Sports': 10, 'Combined Print and E-Book Nonfiction': 15, 'Paperback Books': 10, 'Paperback Business Books': 10, 'Hardcover Business Books': 15, 'Education': 10, 'Race and Civil Rights': 10, 'Hardcover Advice': 15, 'E-Book Fiction': 15, 'Childrens Middle Grade': 15, 'Religion Spirituality and Faith': 10, 'Advice How-To and Miscellaneous': 10, 'Paperback Nonfiction': 10, 'Celebrities': 10, 'Science': 10, 'Hardcover Fiction': 15, 'Travel': 10, 'Relationships': 10, 'Indigenous Americans': 5}

# %%
# Analysis to Rank publishers based on no of books Published

import json
import glob
import csv
publisherBookCount={}
for name in glob.iglob('E:/DataAnalysis4Python_Spring17/bookList/*.*'):
    with open(name,'r') as out:
        fileData=json.load(out)
        for data in fileData:
            publisher=data['book_details'][0]['publisher']
            if  publisher not in publisherBookCount:
                publisherBookCount[publisher]=1
            else:
                publisherBookCount[publisher]=publisherBookCount[publisher]+1

sorted_by_value_hashSet = sorted(publisherBookCount, key = lambda x: publisherBookCount[x], reverse = True)
ranked_dict={}
rank = 1
last_value = publisherBookCount[sorted_by_value_hashSet[0]]
ranked_dict = dict()
for name in sorted_by_value_hashSet:
    this_value = publisherBookCount[name]
    if this_value != last_value:
        rank += 1
    hash={name:publisherBookCount[name]}
    ranked_dict[str(hash)] = rank
    last_value = this_value

sorted_rank_hashSet=sorted(ranked_dict.items(), key=lambda x: x[1])
dir=os.getcwd()
with open(dir+"/"+'question1Output.csv', 'w',newline='') as csvfile:
    fieldnames = ['Rank', 'Publisher Name','No of Publications']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()
    for rankItem in sorted_rank_hashSet:
        words=rankItem[0].split(":")
        publisherName=words[0].translate ({ord(c): "" for c in "!@#$%^&*()[]{};:,'./<>?\|`~-=_+"})
        count=words[1].translate ({ord(c): "" for c in "!@#$%^&*()[]{};:,'./<>?\|`~-=_+"})
        writer.writerow({'Rank': rankItem[1], 'Publisher Name': publisherName,'No of Publications': count})

# %%
str1 = "This is Python Tutorial."
 
str2 = "This is concatenation chapter"
 
int1 = 123
 
print (str1 + " " + str(int1))
# Out:
# This is Python Tutorial. 123
